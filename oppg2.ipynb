# %% [markdown]
# # Oppgave 2 - Klassifikasjon (30%)<a name="oppgave2"></a>

# %% [markdown]
# *Oppgave 2 består av 4 deler med til sammen 15 spørsmål, der alle spørsmål (2a.1), 2a.2) etc.) teller likt. Oppgave 2 teller totalt 30 % av prosjektet.*
#
# **Oppgaven inneholder følgende elementer:**
#
# * Laste inn og utforske et datasett for klassifikasjon
# * Dele datasettet inn i treningssett, valideringssett og testsett
# * Tilpasse en logistisk regresjon og bruke denne til å klassifisere
# * Utføre $k$-nærmeste nabo-klassifikasjon
# * Evaluere godhet av klassifikasjonsresultatene
#
# ## Innholdsfortegnelse
# * [Ble det hjemmeseier?](#intro)
# * [Oppgave 2a) Lese inn og preprosessere data](#oppgave2a)
# * [Oppgave 2b) Logistisk regresjon](#oppgave2b)
# * [Oppgave 2c) $k$-nærmeste-nabo-klassifikasjon](#oppgave2c)
# * [Oppgave 2d) Evaluere beste modeller](#oppgave2d)

# %% [markdown]
# ### Ble det hjemmeseier?<a name="intro"></a>
#
# Datasettet vi skal se på er fra de fire øverste divisjonene i engelsk fotball, i sesongen 2022-2023, og oppgaven går ut på å tilpasse ulike metoder for å predikere om hjemmelaget vinner en gitt kamp utifra data på antall skudd på mål, cornere og forseelser (regelbrudd som fører til frispark eller straffespark).
#
# Mer informasjon om dataene: https://www.football-data.co.uk/englandm.php.

# %%
# importere pakker og funksjoner vi trenger i oppgave 2
import numpy as np
import pandas as pd
import matplotlib.colors as mcolors
import matplotlib.pyplot as plt
import matplotlib.lines as mlines
import seaborn as sns
from scipy import stats
import statsmodels.formula.api as smf
import statsmodels.api as sm
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import cross_val_score

# %% [markdown]
# ### Oppgave 2a) Lese inn og preprosessere data<a name="oppgave2a"></a>
#
# *Oppgave 2a) inneholder 5 spørsmål du skal svare på.*
#
# Datasettet vi skal jobbe med inneholder informasjon om fotballkamper i engelsk fotball. Dataene finnes i fire forskjellige filer, og hver fil inneholder informasjon om kampene i en gitt divisjon. Vi laster inn dataene fra hver fil og kombinerer dem. Etter vi har gjort dette har datasettet $2036$ rader og $106$ kolonner. En gitt rad tilsvarer en gitt kamp og en gitt kolonne tilsvarer en type informasjon (f.eks. antall cornere hjemmelaget hadde). Kolonner som begynner på `H` angår hjemmelaget og `A` angår bortelaget.
#
# I en gitt kamp vinner enten hjemmelaget, eller så vinner ikke hjemmelaget (uavgjort eller borteseier). Resultatet av en kamp er dermed at:
# * hjemmelaget vinner - kodet som $1$
# * hjemmelaget vinner ikke - kodet som $0$.
#
# Kampresultatet ($0$ eller $1$) legger vi i kolonnen `y`, som skal være hva vi vil predikere/klassifisere.
#
# Vi skal ikke se på alle variablene i datasettet, og skal i tillegg til `y` konsentrere oss om kolonnene
#
# * `HST`, `AST`: antall skudd på mål for henholdsvis hjemmelaget og bortelaget
# * `HC`, `AC`: antall cornere for henholdsvis hjemmelaget og bortelaget
# * `HF`, `AF`: antall forseelser for henholdsvis hjemmelaget og bortelaget
#
# Istedenfor å se direkte på disse tre antallene for de to lagene, ser vi heller på *differansene* for hver kamp. Vi lager de nye variablene
#
# * `skudd_paa_maal_diff`=`HST`-`AST`
# * `corner_diff`=`HC`-`AC`
# * `forseelse_diff`=`HF`-`AF`
#
# og dette skal være forklaringsvariablene våre.
#
# _Oppsummert_: Observasjonsenheten i dataene er en fotballkamp, vi har tre forklaringsvariabler `skudd_paa_maal_diff`, `corner_diff` og `forseelse_diff`, mens `y` (0 eller 1) er responsen vi ønsker å predikere.
#
#
# Koden under leser inn dataene, lager de nye variablene og putter alt inn i en ny data frame. Etter det er gjort har vi en datasett med $2036$ rader (kamper) og $4$ kolonner (variabler).

# %%
# Lese inn datasettene ved funksjon fra pandas (df=data frame - vanlig navn å gi et datasett)
plDf = pd.read_csv("https://www.math.ntnu.no/emner/IST100x/ISTx1003/h2023/E0.csv", sep = ',') # Premier League
cDf = pd.read_csv("https://www.math.ntnu.no/emner/IST100x/ISTx1003/h2023/E1.csv", sep = ',') # Championship
l1Df = pd.read_csv("https://www.math.ntnu.no/emner/IST100x/ISTx1003/h2023/E2.csv", sep = ',') # League 1
l2Df = pd.read_csv("https://www.math.ntnu.no/emner/IST100x/ISTx1003/h2023/E3.csv", sep = ',') # League 2

# Sett sammen datasettene til 1 data-frame
df_in=pd.concat([plDf,
                 cDf,
                 l1Df,
                 l2Df], ignore_index = True)
df=pd.concat([pd.Series(np.where(df_in['FTR'] == 'H', 1, 0)),
              df_in['HST']-df_in['AST'], 
              df_in['HC']-df_in['AC'],
              df_in['HF']-df_in['AF']], axis = 1)

# Henter ut de dataene vi er interessert i
df.columns=['y', 'skudd_paa_maal_diff', 'corner_diff', 'forseelse_diff']
print(df.describe())
# Out:
#                  y  skudd_paa_maal_diff  corner_diff  forseelse_diff
# count  2036.000000          2036.000000  2036.000000     2036.000000
# mean      0.432711             0.797151     1.003438       -0.549607
# std       0.495573             3.324189     4.347722        4.583058
# min       0.000000           -11.000000   -17.000000      -17.000000
# 25%       0.000000            -1.000000    -2.000000       -4.000000
# 50%       0.000000             1.000000     1.000000        0.000000
# 75%       1.000000             3.000000     4.000000        2.000000
# max       1.000000            12.000000    16.000000       17.000000

# %% [markdown]
# Videre vil vi dele datasettet vårt inn i tre datasett: et treningssett, et valideringssett og et testsett. Først deler vi data inn i 80\% trening/validering og 20\% test, og deretter deler vi trening/valideringssettet inn i 75\% trening og 25\% validering.

# %%
df_trenval, df_test = train_test_split(df, test_size = 0.2, random_state = 1, stratify = df['y'])
df_tren, df_val = train_test_split(df_trenval, test_size = 0.25, random_state = 1, stratify = df_trenval['y'])
print("treningssett: \n", df_tren.shape)
print(df_tren.describe())
print(df_tren["y"].value_counts())
print("\nvalideringssett: \n", df_val.shape)
print(df_val.describe())
print(df_val["y"].value_counts())
print("\ntestsett: \n", df_test.shape)
print(df_test.describe())
print(df_test["y"].value_counts())
# Out:
# treningssett:
#  (1221, 4)
#                  y  skudd_paa_maal_diff  corner_diff  forseelse_diff
# count  1221.000000          1221.000000  1221.000000     1221.000000
# mean      0.432432             0.933661     1.020475       -0.701065
# std       0.495617             3.286039     4.331025        4.601308
# min       0.000000           -11.000000   -17.000000      -17.000000
# 25%       0.000000            -1.000000    -2.000000       -4.000000
# 50%       0.000000             1.000000     1.000000       -1.000000
# 75%       1.000000             3.000000     4.000000        2.000000
# max       1.000000            12.000000    14.000000       17.000000
# y
# 0    693
# 1    528
# Name: count, dtype: int64
#
# valideringssett:
#  (407, 4)
#                 y  skudd_paa_maal_diff  corner_diff  forseelse_diff
# count  407.000000           407.000000   407.000000      407.000000
# mean     0.432432             0.734644     1.002457       -0.324324
# std      0.496023             3.345956     4.333112        4.589877
# min      0.000000           -10.000000   -12.000000      -16.000000
# 25%      0.000000            -2.000000    -2.000000       -3.000000
# 50%      0.000000             1.000000     1.000000        0.000000
# 75%      1.000000             3.000000     4.000000        3.000000
# max      1.000000            11.000000    16.000000       17.000000
# y
# 0    231
# 1    176
# Name: count, dtype: int64
#
# testsett:
#  (408, 4)
#                 y  skudd_paa_maal_diff  corner_diff  forseelse_diff
# count  408.000000           408.000000   408.000000      408.000000
# mean     0.433824             0.450980     0.953431       -0.321078
# std      0.496210             3.396421     4.421890        4.513409
# min      0.000000            -9.000000   -12.000000      -13.000000
# 25%      0.000000            -2.000000    -2.000000       -4.000000
# 50%      0.000000             1.000000     1.000000        0.000000
# 75%      1.000000             3.000000     4.000000        3.000000
# max      1.000000            12.000000    15.000000       13.000000
# y
# 0    231
# 1    177
# Name: count, dtype: int64

# %% [markdown]
# I denne oppgaven skal vi etterhvert tilpasse logistisk regresjon og $k$-nærmeste nabo-klassifikasjon.
#
# **2a.1)** Hvorfor ønsker vi å dele dataene inn i trening-, validering- og test-sett?
#
# **2a.2)** Hvor stor andel av dataene er nå i hver av de tre settene? Ser de tre datasettene ut til å ha lik fordeling for de tre forklaringsvariablene og responsen?
#
# **2a.3)** La oss si at vi hadde valgt League 1 og 2 som treningssett, Championship som valideringssett, og Premier League som testsett. Hvorfor hadde dette vært dumt?
#
# For å utforske dataene lager vi kryssplott av de tre forklaringsvariablene for treningsdataene og fargelegger punktene fra kampene etter hvorvidt det var hjemmeseier eller ikke. På diagonalen ser vi empiriske tetthetsplott (glattet variant av et histogram). Under har vi også regnet ut empirisk korrelasjonskoeffisient for alle par av variabler.

# %%
sns.pairplot(df_tren, vars = ['skudd_paa_maal_diff','corner_diff','forseelse_diff'],
             hue = 'y', 
             diag_kind = 'kde',
             plot_kws = dict(alpha = 0.4))
plt.show()
# Out:
# c:\Users\a_lun\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\a_lun\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\a_lun\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\a_lun\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\a_lun\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\a_lun\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\a_lun\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\a_lun\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\a_lun\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\a_lun\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\a_lun\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\a_lun\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\a_lun\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\a_lun\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\a_lun\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\a_lun\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\a_lun\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\a_lun\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\a_lun\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\a_lun\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\a_lun\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\a_lun\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\a_lun\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\a_lun\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\a_lun\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\a_lun\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\a_lun\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\a_lun\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\a_lun\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\a_lun\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\a_lun\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\a_lun\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\a_lun\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\a_lun\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\a_lun\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\a_lun\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\a_lun\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\a_lun\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\a_lun\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\a_lun\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\a_lun\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
corr = df_tren.corr()
display(corr.style.background_gradient(cmap = 'coolwarm', axis = None, vmin = -1, vmax = 1))
plt.show()
# Out:
# <style type="text/css">
# #T_a1b16_row0_col0, #T_a1b16_row1_col1, #T_a1b16_row2_col2, #T_a1b16_row3_col3 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_a1b16_row0_col1, #T_a1b16_row1_col0 {
#   background-color: #f7a889;
#   color: #000000;
# }
# #T_a1b16_row0_col2, #T_a1b16_row2_col0 {
#   background-color: #dcdddd;
#   color: #000000;
# }
# #T_a1b16_row0_col3, #T_a1b16_row3_col0 {
#   background-color: #dddcdc;
#   color: #000000;
# }
# #T_a1b16_row1_col2, #T_a1b16_row2_col1 {
#   background-color: #f7b79b;
#   color: #000000;
# }
# #T_a1b16_row1_col3, #T_a1b16_row3_col1 {
#   background-color: #d6dce4;
#   color: #000000;
# }
# #T_a1b16_row2_col3, #T_a1b16_row3_col2 {
#   background-color: #d5dbe5;
#   color: #000000;
# }
# </style>
# <table id="T_a1b16">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a1b16_level0_col0" class="col_heading level0 col0" >y</th>
#       <th id="T_a1b16_level0_col1" class="col_heading level0 col1" >skudd_paa_maal_diff</th>
#       <th id="T_a1b16_level0_col2" class="col_heading level0 col2" >corner_diff</th>
#       <th id="T_a1b16_level0_col3" class="col_heading level0 col3" >forseelse_diff</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a1b16_level0_row0" class="row_heading level0 row0" >y</th>
#       <td id="T_a1b16_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_a1b16_row0_col1" class="data row0 col1" >0.423284</td>
#       <td id="T_a1b16_row0_col2" class="data row0 col2" >-0.004892</td>
#       <td id="T_a1b16_row0_col3" class="data row0 col3" >0.007606</td>
#     </tr>
#     <tr>
#       <th id="T_a1b16_level0_row1" class="row_heading level0 row1" >skudd_paa_maal_diff</th>
#       <td id="T_a1b16_row1_col0" class="data row1 col0" >0.423284</td>
#       <td id="T_a1b16_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_a1b16_row1_col2" class="data row1 col2" >0.343355</td>
#       <td id="T_a1b16_row1_col3" class="data row1 col3" >-0.051163</td>
#     </tr>
#     <tr>
#       <th id="T_a1b16_level0_row2" class="row_heading level0 row2" >corner_diff</th>
#       <td id="T_a1b16_row2_col0" class="data row2 col0" >-0.004892</td>
#       <td id="T_a1b16_row2_col1" class="data row2 col1" >0.343355</td>
#       <td id="T_a1b16_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_a1b16_row2_col3" class="data row2 col3" >-0.055752</td>
#     </tr>
#     <tr>
#       <th id="T_a1b16_level0_row3" class="row_heading level0 row3" >forseelse_diff</th>
#       <td id="T_a1b16_row3_col0" class="data row3 col0" >0.007606</td>
#       <td id="T_a1b16_row3_col1" class="data row3 col1" >-0.051163</td>
#       <td id="T_a1b16_row3_col2" class="data row3 col2" >-0.055752</td>
#       <td id="T_a1b16_row3_col3" class="data row3 col3" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# **2a.4)** Kommenter kort på hva du ser i plottene og utskriften (maks 5 setninger).
#
# **2a.5)** Hvilke(n) av de tre variablene tror du vil være god(e) til å bruke til å predikere om det blir hjemmeseier? Begrunn svaret kort (maks 3 setninger).

# %% [markdown]
# ### Oppgave 2b) Logistisk regresjon<a name="oppgave2b"></a>
#
# *Oppgave 2b) inneholder 5 spørsmål du skal svare på.*
#
# Vi tilpasser en logistisk regresjon til treningssettet, og regner ut feilrate for valideringssettet gitt at vi klassifiserer som suksess (hjemmeseier) når sannsynligheten for hjemmeseier er anslått til minst 0.5.
#
# Dette gjør vi med de samme stegene som det vi gjorde for multippel lineær regresjon:
#
# 1) Bli kjent med dataene ved å se på oppsummeringsmål og ulike typer plott
# 2) Spesifisere en matematisk modell (modellformel)
# 3) Initialisere og tilpasse modellen
# 4) Presentere resultater fra den tilpassede modellen
# 5) Evaluere om modellen passer til dataene
#
# Vi er ferdige med Steg 1, og gjør så Steg 2-4 under.

# %% [markdown]
# **2b.1)** I en kamp der `skudd_paa_maal_diff` er $2$, `corner_diff` er $-2$ og `forseelse_diff` er $6$, hva er ifølge modellen sannsynligheten for at hjemmelaget vinner? Vis utregninger og/eller kode, og oppgi svaret med tre desimaler.
#
# **2b.2)** Hvordan kan du tolke verdien av $$e^{\beta_{\text{skudd\_paa\_maal\_diff}}}$$?

# %%
# Steg 2: Modellformel
formel = "y ~ skudd_paa_maal_diff + corner_diff + forseelse_diff"

# Steg 3: Initialiser modellen 
modell = smf.logit(formel, data = df_tren)

# Tilpass modellen
resultat = modell.fit()

# Steg 4: Presenter koeffisient-verdier (betaer) fra den tilpassede modellen 
print("\nKoeffisentverdier:\n\n", resultat.params)

# Steg 5: Print e^beta for skudd_paa_maal_diff
print("\ne^beta for skudd_paa_maal_diff:\n\n", np.exp(resultat.params['skudd_paa_maal_diff']))
# Out:
# Optimization terminated successfully.
#          Current function value: 0.567874
#          Iterations 6
#
# Koeffisentverdier:
#
#  Intercept             -0.591661
# skudd_paa_maal_diff    0.382565
# corner_diff           -0.100377
# forseelse_diff         0.012009
# dtype: float64
#
# e^beta for skudd_paa_maal_diff:
#
#  1.4660395355692895

# %% [markdown]
# **2b.3)** Hva angir feilraten til modellen? Hvilket datasett er feilraten regnet ut fra? Er du fornøyd med verdien til feilraten?

# %%
# Spesifiser verdi for cutoff
cutoff = 0.5

# Prediker verdi for valideringssettet
val_pred = resultat.predict(exog = df_val)

# Klassifiser som seier for hjemmelaget hvis sannsynligheten for at hjemmelaget vant er over 0.5
y_valpred = np.where(val_pred > cutoff, 1, 0)
y_valobs = df_val['y']

# Finn feilrate
print("Feilrate:", 1 - accuracy_score(y_true = y_valobs, y_pred = y_valpred))
# Out:
# Feilrate: 0.2825552825552825

# %% [markdown]
# Tilpass nå den logistiske regresjonen uten `forseelse_diff` som forklaringsvariabel - ved å kopiere koden over (men ikke den gamle formelen).
#
# **2b.4)** Diskuter kort hvordan koeffisientene ($\beta$-ene) og feilraten endrer seg når `forseelse_diff` tas ut av modellen (maks 3 setninger).
#
# **2b.5)** Med den nye modellen: I en kamp der `skudd_paa_maal_diff` $= 2$, `corner_diff` $= -2$ og `forseelse_diff` $= 6$, hva er sannsynligheten for at hjemmelaget vinner ifølge den nye modellen? Oppgi svaret med tre desimaler.
#
# **2b.6)** Hvis du skal finne en så god som mulig klassifikasjonsmodell med logistisk regresjon, vil du velge modellen med eller uten `forseelse_diff` som forklaringsvariabel? Begrunn kort svaret (maks 3 setninger).

# %%
# her kan du lime inn kode for å svare på 2b.4) til 2b.6)
 # Steg 2: Modellformel uten forseelse_diff
formel = "y ~ skudd_paa_maal_diff + corner_diff"

# Steg 3: Initialiser modellen
modell = smf.logit(formel, data = df_tren)

# Tilpass modellen
resultat = modell.fit()

# Steg 4: Presenter koeffisient-verdier (betaer) fra den tilpassede modellen
print("\nKoeffisientverdier:\n\n", resultat.params)

# Steg 5: Print e^beta for skudd_paa_maal_diff
print("\ne^beta for skudd_paa_maal_diff:\n\n", np.exp(resultat.params['skudd_paa_maal_diff']))
# Out:
# Optimization terminated successfully.
#          Current function value: 0.568168
#          Iterations 6
#
# Koeffisientverdier:
#
#  Intercept             -0.598601
# skudd_paa_maal_diff    0.381953
# corner_diff           -0.101081
# dtype: float64
#
# e^beta for skudd_paa_maal_diff:
#
#  1.465143440356912

# %% [markdown]
# ### Oppgave 2c) $k$-nærmeste-nabo-klassifikasjon<a name="oppgave2c"></a>
#
# *Oppgave 2c) inneholder 2 spørsmål du skal svare på.*
#
# Vi skal nå kun se på forklaringsvariablene `skudd_paa_maal_diff` og `corner_diff`, og tilpasse $k$-nærmeste-nabo-metoden der vi bruker euklidsk avstand som avstandsmål. Vi bruker valideringssettet til å velge $k$.
#
# Koden under tilpasser $k$-nærmeste nabo-klassifikasjon for ulike verdier for $k$, deretter regnes feilrate ut på valideringssettet og plottes.

# %%
knaboer = np.arange(1, 251, step = 2)
val_feilrate = np.empty(len(knaboer))

X_tren = df_tren[['skudd_paa_maal_diff', 'corner_diff']] # bruker bare disse to forklaringsvariablene
Y_tren = df_tren['y']
X_val = df_val[['skudd_paa_maal_diff', 'corner_diff']] 
Y_val = df_val['y']

for i,k in enumerate(knaboer):
    
    # Initialiser kNN med  k neighbors
    knn = KNeighborsClassifier(n_neighbors = k, p = 2) # p = 2 gir euklidsk avstand

    # Tilpass modellen med treningssettet
    knn.fit(X_tren, Y_tren)
    
    # Beregn feilrate på valideringssett
    # score er accuracy = "andel korrekt"
    val_feilrate[i] = 1 - knn.score(X_val, Y_val)
    
# Lage plott
plt.title('k-NN for ulike verdier av antall naboer k')
plt.plot(knaboer, val_feilrate, label = 'Feilrate på valideringssettet')
plt.legend()
plt.xlabel('Antall naboer k')
plt.ylabel('Feilrate')
plt.show()

valres=np.vstack((knaboer, val_feilrate))
print("Valideringsfeilrate:")
print(valres.T)
# Out:
# Valideringsfeilrate:
# [[  1.           0.35626536]
#  [  3.           0.35135135]
#  [  5.           0.33169533]
#  [  7.           0.32923833]
#  [  9.           0.32678133]
#  [ 11.           0.32186732]
#  [ 13.           0.33169533]
#  [ 15.           0.32678133]
#  [ 17.           0.31203931]
#  [ 19.           0.32923833]
#  [ 21.           0.31449631]
#  [ 23.           0.32186732]
#  [ 25.           0.31203931]
#  [ 27.           0.3046683 ]
#  [ 29.           0.30958231]
#  [ 31.           0.3046683 ]
#  [ 33.           0.2972973 ]
#  [ 35.           0.3022113 ]
#  [ 37.           0.2997543 ]
#  [ 39.           0.30712531]
#  [ 41.           0.30958231]
#  [ 43.           0.30958231]
#  [ 45.           0.30712531]
#  [ 47.           0.3046683 ]
#  [ 49.           0.3046683 ]
#  [ 51.           0.30712531]
#  [ 53.           0.2972973 ]
#  [ 55.           0.2972973 ]
#  [ 57.           0.2972973 ]
#  [ 59.           0.29484029]
#  [ 61.           0.29484029]
#  [ 63.           0.2972973 ]
#  [ 65.           0.2997543 ]
#  [ 67.           0.2997543 ]
#  [ 69.           0.3022113 ]
#  [ 71.           0.2997543 ]
#  [ 73.           0.2972973 ]
#  [ 75.           0.2997543 ]
#  [ 77.           0.2972973 ]
#  [ 79.           0.3022113 ]
#  [ 81.           0.3022113 ]
#  [ 83.           0.2972973 ]
#  [ 85.           0.29484029]
#  [ 87.           0.29238329]
#  [ 89.           0.29484029]
#  [ 91.           0.28009828]
#  [ 93.           0.29238329]
#  [ 95.           0.2997543 ]
#  [ 97.           0.2972973 ]
#  [ 99.           0.29484029]
#  [101.           0.2972973 ]
#  [103.           0.2972973 ]
#  [105.           0.28746929]
#  [107.           0.28746929]
#  [109.           0.28501229]
#  [111.           0.28255528]
#  [113.           0.28501229]
#  [115.           0.28501229]
#  [117.           0.28501229]
#  [119.           0.29484029]
#  [121.           0.29484029]
#  [123.           0.2972973 ]
#  [125.           0.3022113 ]
#  [127.           0.3022113 ]
#  [129.           0.3022113 ]
#  [131.           0.28992629]
#  [133.           0.28746929]
#  [135.           0.28746929]
#  [137.           0.28992629]
#  [139.           0.27764128]
#  [141.           0.28992629]
#  [143.           0.28501229]
#  [145.           0.28255528]
#  [147.           0.2972973 ]
#  [149.           0.28992629]
#  [151.           0.29484029]
#  [153.           0.28501229]
#  [155.           0.28501229]
#  [157.           0.28992629]
#  [159.           0.2972973 ]
#  [161.           0.2972973 ]
#  [163.           0.29484029]
#  [165.           0.29484029]
#  [167.           0.2997543 ]
#  [169.           0.3022113 ]
#  [171.           0.29484029]
#  [173.           0.2997543 ]
#  [175.           0.29238329]
#  [177.           0.29484029]
#  [179.           0.29484029]
#  [181.           0.28992629]
#  [183.           0.28992629]
#  [185.           0.29484029]
#  [187.           0.29484029]
#  [189.           0.29238329]
#  [191.           0.28255528]
#  [193.           0.2997543 ]
#  [195.           0.30958231]
#  [197.           0.3046683 ]
#  [199.           0.2997543 ]
#  [201.           0.3022113 ]
#  [203.           0.3022113 ]
#  [205.           0.3022113 ]
#  [207.           0.2997543 ]
#  [209.           0.3022113 ]
#  [211.           0.2997543 ]
#  [213.           0.3046683 ]
#  [215.           0.30958231]
#  [217.           0.30712531]
#  [219.           0.2997543 ]
#  [221.           0.2972973 ]
#  [223.           0.3022113 ]
#  [225.           0.3022113 ]
#  [227.           0.3022113 ]
#  [229.           0.3022113 ]
#  [231.           0.2997543 ]
#  [233.           0.29238329]
#  [235.           0.29238329]
#  [237.           0.29238329]
#  [239.           0.28746929]
#  [241.           0.28746929]
#  [243.           0.28746929]
#  [245.           0.29238329]
#  [247.           0.29238329]
#  [249.           0.29238329]]

# %% [markdown]
# #### Utfører kryssvalidering for å finne beste k_verdi

# %%
X_tren = df_tren[['skudd_paa_maal_diff', 'corner_diff']] # bruker bare disse to forklaringsvariablene
Y_tren = df_tren['y']
X_val = df_val[['skudd_paa_maal_diff', 'corner_diff']] 
Y_val = df_val['y']

val_accuracies = []
cv = 15

X_val_np = np.ascontiguousarray(X_val)
Y_val_np = np.ascontiguousarray(Y_val)

for k in knaboer:
    knn = KNeighborsClassifier(n_neighbors=k, p = 2)
    
    scores = cross_val_score(knn, X_val_np, Y_val_np, cv=cv, scoring='accuracy')
    
    mean_accuracy = np.mean(scores)
    val_accuracies.append(mean_accuracy)
    
    print(f'Antall naboer (k): {k}, Kryssvalideringsbretter (cv): {cv} , Gjennomsnittlig nøyaktighet: {mean_accuracy}')

plt.plot(knaboer, val_accuracies, marker='o')
plt.title('Mean Accuracy vs. Number of Neighbors')
plt.xlabel('Number of Neighbors (k)')
plt.ylabel('Mean Accuracy')
plt.grid(True)
plt.show()
# Out:
# Antall naboer (k): 1, Kryssvalideringsbretter (cv): 15 , Gjennomsnittlig nøyaktighet: 0.6291887125220459
# Antall naboer (k): 3, Kryssvalideringsbretter (cv): 15 , Gjennomsnittlig nøyaktighet: 0.6908289241622574
# Antall naboer (k): 5, Kryssvalideringsbretter (cv): 15 , Gjennomsnittlig nøyaktighet: 0.6831569664902999
# Antall naboer (k): 7, Kryssvalideringsbretter (cv): 15 , Gjennomsnittlig nøyaktighet: 0.697795414462081
# Antall naboer (k): 9, Kryssvalideringsbretter (cv): 15 , Gjennomsnittlig nøyaktighet: 0.6880070546737213
# Antall naboer (k): 11, Kryssvalideringsbretter (cv): 15 , Gjennomsnittlig nøyaktighet: 0.7002645502645503
# Antall naboer (k): 13, Kryssvalideringsbretter (cv): 15 , Gjennomsnittlig nøyaktighet: 0.6731922398589065
# Antall naboer (k): 15, Kryssvalideringsbretter (cv): 15 , Gjennomsnittlig nøyaktighet: 0.6829805996472662
# Antall naboer (k): 17, Kryssvalideringsbretter (cv): 15 , Gjennomsnittlig nøyaktighet: 0.6757495590828925
# Antall naboer (k): 19, Kryssvalideringsbretter (cv): 15 , Gjennomsnittlig nøyaktighet: 0.6732804232804234
# Antall naboer (k): 21, Kryssvalideringsbretter (cv): 15 , Gjennomsnittlig nøyaktighet: 0.6733686067019399
# Antall naboer (k): 23, Kryssvalideringsbretter (cv): 15 , Gjennomsnittlig nøyaktighet: 0.6781305114638448
# Antall naboer (k): 25, Kryssvalideringsbretter (cv): 15 , Gjennomsnittlig nøyaktighet: 0.6954144620811288
# Antall naboer (k): 27, Kryssvalideringsbretter (cv): 15 , Gjennomsnittlig nøyaktighet: 0.6857142857142856
# Antall naboer (k): 29, Kryssvalideringsbretter (cv): 15 , Gjennomsnittlig nøyaktighet: 0.6929453262786596
# Antall naboer (k): 31, Kryssvalideringsbretter (cv): 15 , Gjennomsnittlig nøyaktighet: 0.6978835978835979
# Antall naboer (k): 33, Kryssvalideringsbretter (cv): 15 , Gjennomsnittlig nøyaktighet: 0.7076719576719577
# Antall naboer (k): 35, Kryssvalideringsbretter (cv): 15 , Gjennomsnittlig nøyaktighet: 0.7149029982363316
# Antall naboer (k): 37, Kryssvalideringsbretter (cv): 15 , Gjennomsnittlig nøyaktighet: 0.7051146384479717
# Antall naboer (k): 39, Kryssvalideringsbretter (cv): 15 , Gjennomsnittlig nøyaktighet: 0.7199294532627866
# Antall naboer (k): 41, Kryssvalideringsbretter (cv): 15 , Gjennomsnittlig nøyaktighet: 0.7078483245149912
# Antall naboer (k): 43, Kryssvalideringsbretter (cv): 15 , Gjennomsnittlig nøyaktighet: 0.695326278659612
# Antall naboer (k): 45, Kryssvalideringsbretter (cv): 15 , Gjennomsnittlig nøyaktighet: 0.7102292768959436
# Antall naboer (k): 47, Kryssvalideringsbretter (cv): 15 , Gjennomsnittlig nøyaktighet: 0.7052910052910054
# Antall naboer (k): 49, Kryssvalideringsbretter (cv): 15 , Gjennomsnittlig nøyaktighet: 0.7076719576719577
# Antall naboer (k): 51, Kryssvalideringsbretter (cv): 15 , Gjennomsnittlig nøyaktighet: 0.7174603174603175
# Antall naboer (k): 53, Kryssvalideringsbretter (cv): 15 , Gjennomsnittlig nøyaktighet: 0.7149911816578485
# Antall naboer (k): 55, Kryssvalideringsbretter (cv): 15 , Gjennomsnittlig nøyaktighet: 0.7002645502645504
# Antall naboer (k): 57, Kryssvalideringsbretter (cv): 15 , Gjennomsnittlig nøyaktighet: 0.7076719576719576
# Antall naboer (k): 59, Kryssvalideringsbretter (cv): 15 , Gjennomsnittlig nøyaktighet: 0.7028218694885362
# Antall naboer (k): 61, Kryssvalideringsbretter (cv): 15 , Gjennomsnittlig nøyaktighet: 0.7027336860670194
# Antall naboer (k): 63, Kryssvalideringsbretter (cv): 15 , Gjennomsnittlig nøyaktighet: 0.7076719576719577
# Antall naboer (k): 65, Kryssvalideringsbretter (cv): 15 , Gjennomsnittlig nøyaktighet: 0.7051146384479718
# Antall naboer (k): 67, Kryssvalideringsbretter (cv): 15 , Gjennomsnittlig nøyaktighet: 0.7101410934744268
# Antall naboer (k): 69, Kryssvalideringsbretter (cv): 15 , Gjennomsnittlig nøyaktighet: 0.7076719576719577
# Antall naboer (k): 71, Kryssvalideringsbretter (cv): 15 , Gjennomsnittlig nøyaktighet: 0.712610229276896
# Antall naboer (k): 73, Kryssvalideringsbretter (cv): 15 , Gjennomsnittlig nøyaktighet: 0.7027336860670196
# Antall naboer (k): 75, Kryssvalideringsbretter (cv): 15 , Gjennomsnittlig nøyaktighet: 0.7076719576719577
# Antall naboer (k): 77, Kryssvalideringsbretter (cv): 15 , Gjennomsnittlig nøyaktighet: 0.7052028218694886
# Antall naboer (k): 79, Kryssvalideringsbretter (cv): 15 , Gjennomsnittlig nøyaktighet: 0.695326278659612
# Antall naboer (k): 81, Kryssvalideringsbretter (cv): 15 , Gjennomsnittlig nøyaktighet: 0.6929453262786596
# Antall naboer (k): 83, Kryssvalideringsbretter (cv): 15 , Gjennomsnittlig nøyaktighet: 0.7027336860670194
# Antall naboer (k): 85, Kryssvalideringsbretter (cv): 15 , Gjennomsnittlig nøyaktighet: 0.7027336860670192
# Antall naboer (k): 87, Kryssvalideringsbretter (cv): 15 , Gjennomsnittlig nøyaktighet: 0.7003527336860671
# Antall naboer (k): 89, Kryssvalideringsbretter (cv): 15 , Gjennomsnittlig nøyaktighet: 0.7052910052910054
# Antall naboer (k): 91, Kryssvalideringsbretter (cv): 15 , Gjennomsnittlig nøyaktighet: 0.7174603174603174
# Antall naboer (k): 93, Kryssvalideringsbretter (cv): 15 , Gjennomsnittlig nøyaktighet: 0.7076719576719577
# Antall naboer (k): 95, Kryssvalideringsbretter (cv): 15 , Gjennomsnittlig nøyaktighet: 0.7027336860670194
# Antall naboer (k): 97, Kryssvalideringsbretter (cv): 15 , Gjennomsnittlig nøyaktighet: 0.7051146384479718
# Antall naboer (k): 99, Kryssvalideringsbretter (cv): 15 , Gjennomsnittlig nøyaktighet: 0.7028218694885362
# Antall naboer (k): 101, Kryssvalideringsbretter (cv): 15 , Gjennomsnittlig nøyaktighet: 0.7027336860670194
# Antall naboer (k): 103, Kryssvalideringsbretter (cv): 15 , Gjennomsnittlig nøyaktighet: 0.6977954144620812
# Antall naboer (k): 105, Kryssvalideringsbretter (cv): 15 , Gjennomsnittlig nøyaktighet: 0.7075837742504409
# Antall naboer (k): 107, Kryssvalideringsbretter (cv): 15 , Gjennomsnittlig nøyaktighet: 0.7052028218694885
# Antall naboer (k): 109, Kryssvalideringsbretter (cv): 15 , Gjennomsnittlig nøyaktighet: 0.7075837742504409
# Antall naboer (k): 111, Kryssvalideringsbretter (cv): 15 , Gjennomsnittlig nøyaktighet: 0.7076719576719577
# Antall naboer (k): 113, Kryssvalideringsbretter (cv): 15 , Gjennomsnittlig nøyaktighet: 0.7076719576719577
# Antall naboer (k): 115, Kryssvalideringsbretter (cv): 15 , Gjennomsnittlig nøyaktighet: 0.7002645502645504
# Antall naboer (k): 117, Kryssvalideringsbretter (cv): 15 , Gjennomsnittlig nøyaktighet: 0.7126984126984127
# Antall naboer (k): 119, Kryssvalideringsbretter (cv): 15 , Gjennomsnittlig nøyaktighet: 0.7076719576719577
# Antall naboer (k): 121, Kryssvalideringsbretter (cv): 15 , Gjennomsnittlig nøyaktighet: 0.6977954144620812
# Antall naboer (k): 123, Kryssvalideringsbretter (cv): 15 , Gjennomsnittlig nøyaktighet: 0.7026455026455026
# Antall naboer (k): 125, Kryssvalideringsbretter (cv): 15 , Gjennomsnittlig nøyaktighet: 0.7028218694885361
# Antall naboer (k): 127, Kryssvalideringsbretter (cv): 15 , Gjennomsnittlig nøyaktighet: 0.7028218694885361
# Antall naboer (k): 129, Kryssvalideringsbretter (cv): 15 , Gjennomsnittlig nøyaktighet: 0.6880070546737213
# Antall naboer (k): 131, Kryssvalideringsbretter (cv): 15 , Gjennomsnittlig nøyaktighet: 0.6928571428571428
# Antall naboer (k): 133, Kryssvalideringsbretter (cv): 15 , Gjennomsnittlig nøyaktighet: 0.695326278659612
# Antall naboer (k): 135, Kryssvalideringsbretter (cv): 15 , Gjennomsnittlig nøyaktighet: 0.6953262786596119
# Antall naboer (k): 137, Kryssvalideringsbretter (cv): 15 , Gjennomsnittlig nøyaktighet: 0.7002645502645503
# Antall naboer (k): 139, Kryssvalideringsbretter (cv): 15 , Gjennomsnittlig nøyaktighet: 0.7002645502645503
# Antall naboer (k): 141, Kryssvalideringsbretter (cv): 15 , Gjennomsnittlig nøyaktighet: 0.7002645502645503
# Antall naboer (k): 143, Kryssvalideringsbretter (cv): 15 , Gjennomsnittlig nøyaktighet: 0.6929453262786596
# Antall naboer (k): 145, Kryssvalideringsbretter (cv): 15 , Gjennomsnittlig nøyaktighet: 0.6929453262786596
# Antall naboer (k): 147, Kryssvalideringsbretter (cv): 15 , Gjennomsnittlig nøyaktighet: 0.6929453262786596
# Antall naboer (k): 149, Kryssvalideringsbretter (cv): 15 , Gjennomsnittlig nøyaktighet: 0.6929453262786596
# Antall naboer (k): 151, Kryssvalideringsbretter (cv): 15 , Gjennomsnittlig nøyaktighet: 0.6954144620811287
# Antall naboer (k): 153, Kryssvalideringsbretter (cv): 15 , Gjennomsnittlig nøyaktighet: 0.700352733686067
# Antall naboer (k): 155, Kryssvalideringsbretter (cv): 15 , Gjennomsnittlig nøyaktighet: 0.6928571428571428
# Antall naboer (k): 157, Kryssvalideringsbretter (cv): 15 , Gjennomsnittlig nøyaktighet: 0.7052028218694885
# Antall naboer (k): 159, Kryssvalideringsbretter (cv): 15 , Gjennomsnittlig nøyaktighet: 0.7027336860670192
# Antall naboer (k): 161, Kryssvalideringsbretter (cv): 15 , Gjennomsnittlig nøyaktighet: 0.6978835978835979
# Antall naboer (k): 163, Kryssvalideringsbretter (cv): 15 , Gjennomsnittlig nøyaktighet: 0.7052910052910053
# Antall naboer (k): 165, Kryssvalideringsbretter (cv): 15 , Gjennomsnittlig nøyaktighet: 0.7052028218694885
# Antall naboer (k): 167, Kryssvalideringsbretter (cv): 15 , Gjennomsnittlig nøyaktighet: 0.6928571428571428
# Antall naboer (k): 169, Kryssvalideringsbretter (cv): 15 , Gjennomsnittlig nøyaktighet: 0.6928571428571427
# Antall naboer (k): 171, Kryssvalideringsbretter (cv): 15 , Gjennomsnittlig nøyaktighet: 0.7000881834215168
# Antall naboer (k): 173, Kryssvalideringsbretter (cv): 15 , Gjennomsnittlig nøyaktighet: 0.7074955908289241
# Antall naboer (k): 175, Kryssvalideringsbretter (cv): 15 , Gjennomsnittlig nøyaktighet: 0.7051146384479717
# Antall naboer (k): 177, Kryssvalideringsbretter (cv): 15 , Gjennomsnittlig nøyaktighet: 0.7026455026455026
# Antall naboer (k): 179, Kryssvalideringsbretter (cv): 15 , Gjennomsnittlig nøyaktighet: 0.6952380952380952
# Antall naboer (k): 181, Kryssvalideringsbretter (cv): 15 , Gjennomsnittlig nøyaktighet: 0.7026455026455026
# Antall naboer (k): 183, Kryssvalideringsbretter (cv): 15 , Gjennomsnittlig nøyaktighet: 0.7001763668430335
# Antall naboer (k): 185, Kryssvalideringsbretter (cv): 15 , Gjennomsnittlig nøyaktighet: 0.6952380952380952
# Antall naboer (k): 187, Kryssvalideringsbretter (cv): 15 , Gjennomsnittlig nøyaktighet: 0.6903880070546738
# Antall naboer (k): 189, Kryssvalideringsbretter (cv): 15 , Gjennomsnittlig nøyaktighet: 0.6828924162257497
# Antall naboer (k): 191, Kryssvalideringsbretter (cv): 15 , Gjennomsnittlig nøyaktighet: 0.6926807760141095
# Antall naboer (k): 193, Kryssvalideringsbretter (cv): 15 , Gjennomsnittlig nøyaktighet: 0.6926807760141095
# Antall naboer (k): 195, Kryssvalideringsbretter (cv): 15 , Gjennomsnittlig nøyaktighet: 0.682804232804233
# Antall naboer (k): 197, Kryssvalideringsbretter (cv): 15 , Gjennomsnittlig nøyaktighet: 0.6852733686067022
# Antall naboer (k): 199, Kryssvalideringsbretter (cv): 15 , Gjennomsnittlig nøyaktighet: 0.6926807760141095
# Antall naboer (k): 201, Kryssvalideringsbretter (cv): 15 , Gjennomsnittlig nøyaktighet: 0.6779541446208114
# Antall naboer (k): 203, Kryssvalideringsbretter (cv): 15 , Gjennomsnittlig nøyaktighet: 0.6777777777777779
# Antall naboer (k): 205, Kryssvalideringsbretter (cv): 15 , Gjennomsnittlig nøyaktighet: 0.682804232804233
# Antall naboer (k): 207, Kryssvalideringsbretter (cv): 15 , Gjennomsnittlig nøyaktighet: 0.6902998236331572
# Antall naboer (k): 209, Kryssvalideringsbretter (cv): 15 , Gjennomsnittlig nøyaktighet: 0.6877425044091712
# Antall naboer (k): 211, Kryssvalideringsbretter (cv): 15 , Gjennomsnittlig nøyaktighet: 0.6779541446208113
# Antall naboer (k): 213, Kryssvalideringsbretter (cv): 15 , Gjennomsnittlig nøyaktighet: 0.6757495590828925
# Antall naboer (k): 215, Kryssvalideringsbretter (cv): 15 , Gjennomsnittlig nøyaktighet: 0.6756613756613757
# Antall naboer (k): 217, Kryssvalideringsbretter (cv): 15 , Gjennomsnittlig nøyaktighet: 0.678130511463845
# Antall naboer (k): 219, Kryssvalideringsbretter (cv): 15 , Gjennomsnittlig nøyaktighet: 0.6708112874779543
# Antall naboer (k): 221, Kryssvalideringsbretter (cv): 15 , Gjennomsnittlig nøyaktighet: 0.6684303350970018
# Antall naboer (k): 223, Kryssvalideringsbretter (cv): 15 , Gjennomsnittlig nøyaktighet: 0.6731922398589066
# Antall naboer (k): 225, Kryssvalideringsbretter (cv): 15 , Gjennomsnittlig nøyaktighet: 0.6756613756613757
# Antall naboer (k): 227, Kryssvalideringsbretter (cv): 15 , Gjennomsnittlig nøyaktighet: 0.6731922398589066
# Antall naboer (k): 229, Kryssvalideringsbretter (cv): 15 , Gjennomsnittlig nøyaktighet: 0.6756613756613756
# Antall naboer (k): 231, Kryssvalideringsbretter (cv): 15 , Gjennomsnittlig nøyaktighet: 0.6755731922398589
# Antall naboer (k): 233, Kryssvalideringsbretter (cv): 15 , Gjennomsnittlig nøyaktighet: 0.6706349206349206
# Antall naboer (k): 235, Kryssvalideringsbretter (cv): 15 , Gjennomsnittlig nøyaktighet: 0.6706349206349207
# Antall naboer (k): 237, Kryssvalideringsbretter (cv): 15 , Gjennomsnittlig nøyaktighet: 0.6682539682539682
# Antall naboer (k): 239, Kryssvalideringsbretter (cv): 15 , Gjennomsnittlig nøyaktighet: 0.6657848324514991
# Antall naboer (k): 241, Kryssvalideringsbretter (cv): 15 , Gjennomsnittlig nøyaktighet: 0.665873015873016
# Antall naboer (k): 243, Kryssvalideringsbretter (cv): 15 , Gjennomsnittlig nøyaktighet: 0.6609347442680776
# Antall naboer (k): 245, Kryssvalideringsbretter (cv): 15 , Gjennomsnittlig nøyaktighet: 0.668342151675485
# Antall naboer (k): 247, Kryssvalideringsbretter (cv): 15 , Gjennomsnittlig nøyaktighet: 0.6634038800705467
# Antall naboer (k): 249, Kryssvalideringsbretter (cv): 15 , Gjennomsnittlig nøyaktighet: 0.668342151675485

# %% [markdown]
# **2c.1)** Påstand: kNN kan bare brukes når vi har maksimalt to forklaringsvariabler. Fleip eller fakta?
#
# **2c.2)** Hvilken verdi av $k$ vil du velge? Hvorfor?

# %% [markdown]
# ### Oppgave 2d) Evaluere beste modeller<a name="oppgave2d"></a>
#
# *Oppgave 2d) inneholder 2 spørsmål du skal svare på.*
#
# Nå tar vi frem testsettet og sammenligner den beste modellen for logistisk regresjon med den beste for $k$-nærmeste-nabo-klassifikasjon.
#
# **Gjør nødvendige endringer i koden under.**
#
# **2d.1)** Gjør logistisk regresjon eller $k$-nærmeste-nabo-klassifikasjon det best på fotballkampdataene?
#
# **2d.2)** Drøft klassegrensene (plottet under) for de to beste modellene (én logistisk regresjon og én kNN). Hva forteller klassegrensene deg om problemet? Skriv maksimalt 3 setninger.

# %%
from sklearn.metrics import accuracy_score
import numpy as np

# Logistisk regresjon
# Bruk resultat fra tilpasningen av logistisk regresjonsmodell
test_pred_logistisk = resultat.predict(df_test[['skudd_paa_maal_diff', 'corner_diff']])
cutoff = 0.5
y_testpred_logistisk = np.where(test_pred_logistisk > cutoff, 1, 0)
y_testobs = df_test['y']
feilrate_logistisk = 1 - accuracy_score(y_true = y_testobs, y_pred = y_testpred_logistisk)
print("Feilrate logistisk regresjon:", feilrate_logistisk)

# k-NN med k = 111
bestek = 111
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier(n_neighbors = bestek, p = 2)
knn.fit(df_tren[['skudd_paa_maal_diff', 'corner_diff']], df_tren['y'])
X_test = df_test[['skudd_paa_maal_diff', 'corner_diff']]
feilrate_knn = 1 - knn.score(X_test, df_test['y'])
print("Feilrate kNN:", feilrate_knn)
# Out:
# Feilrate logistisk regresjon: 0.31862745098039214
# Feilrate kNN: 0.31862745098039214

# %%
# Plotting av klassegrensene for de beste modellene!

# Set the data to be plotted
n = 100  # Step size

# Function to add jitter to data
def jitter(data, factor=0.2):
    # Add random noise to the data
    return data + np.random.uniform(-factor, factor, data.shape)

# Create a grid for plotting
x_min, x_max = X_tren['skudd_paa_maal_diff'].min() - 0.5, X_tren['skudd_paa_maal_diff'].max() + 0.5
y_min, y_max = X_tren['corner_diff'].min() - 0.5, X_tren['corner_diff'].max() + 0.5
xx, yy = np.meshgrid(np.linspace(x_min, x_max, n),
                     np.linspace(y_min, y_max, n))

# Create a temporary DataFrame with feature names
temp_df = pd.DataFrame(np.c_[xx.ravel(), yy.ravel()], columns=['skudd_paa_maal_diff', 'corner_diff'])

# Predict using the KNeighborsClassifier with temporary feature names
Z_knn = knn.predict(temp_df)

# Reshape Z_knn to match the shape of xx
Z_knn = Z_knn.reshape(xx.shape)

# Plot the class boundary for Logistic Regression
beta0 = resultat.params[0]
beta1 = resultat.params['skudd_paa_maal_diff']
beta2 = resultat.params['corner_diff']
x_lr = np.linspace(-3, 5.25, n)
y_lr = -beta0 / beta2 - x_lr * beta1 / beta2

# Create a custom color map for the plot
cmap = mcolors.ListedColormap(['#d8b365', '#5ab4ac'])

# Create a figure and axes
fig, ax = plt.subplots(figsize=(10, 8))

# Plot the decision boundaries
ax.contourf(xx, yy, Z_knn, cmap=cmap, alpha=0.6, levels=1, antialiased=True, linestyles='dashed')
ax.plot(x_lr, y_lr, color = "black", label='Logistic Class Boundary', linewidth=2)

# Scatter plot for the training data
jittered_X_tren = jitter(X_tren[['skudd_paa_maal_diff', 'corner_diff']].values)
scatter = ax.scatter(jittered_X_tren[:, 0], jittered_X_tren[:, 1], c=df_tren['y'], cmap=cmap, s=10)
plt.colorbar(scatter, ax=ax, label='Class')

# Add labels and a title
ax.set_xlabel('Skudd på mål-differanse', fontsize=14)
ax.set_ylabel('Corner-differense', fontsize=14)
ax.set_title('Klassegrense for de beste modellene', fontsize=16)

# Create custom legend elements for Klasse 0 and Klasse 1
legend_elements = [
    mlines.Line2D([], [], marker='s', color='w', markerfacecolor=cmap(0), markersize=10, label='Klasse 0 (KNN)', linestyle='None'),
    mlines.Line2D([], [], marker='s', color='w', markerfacecolor=cmap(1), markersize=10, label='Klasse 1 (KNN)', linestyle='None'),
    mlines.Line2D([], [], color='black', lw=2, label='Klassegrense (logistisk regresjon)')
]

# Add legend for class boundaries
ax.legend(handles=legend_elements, title="Klasser", loc='lower right')

# Show the plot
plt.show()
# Out:
# C:\Users\a_lun\AppData\Local\Temp\ipykernel_27872\2063302411.py:27: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   beta0 = resultat.params[0]

# %% [markdown]
# [Til toppen.](#top)
